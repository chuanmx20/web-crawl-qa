# %%
# 用于创建assistant
instructions = """
The Draw.io Guide, designed to assist users with draw.io, emphasizes direct, practical assistance without directing users to external documentation. 
It clearly lists relevant clickable elements such as menu options (<File>, <Edit>), toolbar buttons (<Undo>, <Redo>), sidebar sections (<Search Shapes>, <More Shapes>), dialog box options (<Save>, <Export>), and right-click context menu options (<Group>, <Ungroup>) using angle brackets for emphasis. 
This approach helps users quickly understand and find various features in draw.io. The guide's information is based on official draw.io tutorials and practical tips, and it clarifies ambiguous requests to provide accurate guidance. 
Its communication is straightforward and focused on delivering clear instructions for efficient navigation within draw.io."""

# %%
from openai import OpenAI

client = OpenAI()

# 根据instructions创建一个assistant
assistant = client.beta.assistants.create(
    name="Draw.io Guide",
    instructions=instructions,
    tools=[{"type": "code_interpreter"}],
    model="gpt-4-1106-preview"
)

# 创建一个thread，用于对一个用户的对话
thread = client.beta.threads.create()

# %%
# 创建一个message，用于用户的第一条消息
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="How to align shapes?"
)

# 创建一个run，用于执行assistant
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
)

# 等待assistant执行完成
while True:
  run = client.beta.threads.runs.retrieve(
      thread_id=thread.id,
      run_id=run.id
  )
  if run.status == "completed":
      break
  print(run.status)
# Out:
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress

# %%
# 创建一个message，用于用户的第一条消息
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="How to save the file?"
)

# 创建一个run，用于执行assistant
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
)

# 等待assistant执行完成
while True:
  run = client.beta.threads.runs.retrieve(
      thread_id=thread.id,
      run_id=run.id
  )
  if run.status == "completed":
      break
  print(run.status)
# Out:
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress
# in_progress

# %%
# 列出一条thread中所有的用户和assistant的消息
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)

for message in messages:
    print("----------------")
    print(message.role)
    if (message.content[0].type == "text"):
        print(message.content[0].text.value)
    else:
        print(message.content[0])
# Out:
# ----------------
# assistant
# To save your draw.io diagram, follow these steps:
#
# 1. **Save Command**:
#    - Go to the menu bar at the top of the draw.io interface and click on <File>.
#
# 2. **Choose Save Option**:
#    - From the drop-down menu, select <Save> if you are saving the diagram for the first time or want to save the changes to the existing location.
#
# 3. **Saving to Different Locations**:
#    - If you want to save the diagram to a specific location or service, you will see options like <Save As> or <Save to Cloud>. Choose the appropriate option based on where you wish to save your diagram. You may be given choices such as saving to your computer, Google Drive, OneDrive, Dropbox, GitHub, or other integrated cloud services.
#
# 4. **Name the File (First Save or Save As)**:
#    - If this is the first time you are saving the diagram or you are using the "Save As" feature, a dialog box will appear prompting you to name your file and choose a location to save it. Enter the file name and select the desired location.
#
# 5. **Complete the Save Process**:
#    - Click on the <Save> button within the dialog box to complete the saving process.
#
# The process could differ slightly depending on whether you're using the online version of draw.io or the desktop application, and also depending on the specific storage integrations you are using (such as Google Drive or another cloud service).
#
# Keep in mind that the platform's autosave feature may periodically save your work if you're logged in and working on a diagram associated with your cloud account. However, it's good practice to manually save your work regularly to prevent data loss.
# ----------------
# user
# How to save the file?
# ----------------
# assistant
# To align shapes in draw.io (also known as diagrams.net), you can use the alignment tools provided in the format toolbar. Here's a step-by-step guide to help you align shapes:
#
# 1. **Select Shapes**:
#    - Click on the shapes you want to align while holding the `Shift` key to select multiple shapes.
#
# 2. **Choose Alignment Option**:
#    - Once your shapes are selected, go to the format toolbar located at the top of the canvas.
#    - Locate the alignment options in the toolbar. These are typically represented by icons showing lines aligned to the left, center, or right, and top, middle, or bottom.
#
# 3. **Apply Alignment**:
#    - Click on the desired alignment button to align the shapes accordingly.
#       - **Left Align**: Aligns the left edges of the selected shapes.
#       - **Center Align**: Aligns the centers of the selected shapes horizontally.
#       - **Right Align**: Aligns the right edges of the selected shapes.
#       - **Top Align**: Aligns the top edges of the selected shapes.
#       - **Middle Align**: Aligns the centers of the selected shapes vertically.
#       - **Bottom Align**: Aligns the bottom edges of the selected shapes.
#
# 4. **Use Arrange Menu (Alternative Method)**:
#    - Alternatively, you can use the <Arrange> menu for more alignment options.
#    - With shapes selected, click on the <Arrange> menu at the top.
#    - Hover over the <Align> submenu to see the same list of alignment options.
#    - Click on the alignment you want to apply.
#
# 5. **Adjust Spacing (Optional)**:
#    - If you want to distribute the shapes evenly, you can use the distribute options located near the alignment tools in the format toolbar or under the <Arrange> menu in the <Distribute> submenu.
#
# Remember that the alignment will be based on the bounding boxes of the selected shapes. It's important to select all the shapes you want to align before using these alignment tools. If you only select one shape, these tools will not have any visible effect, as there's nothing to align that single shape with.
# ----------------
# user
# How to align shapes?

# %%
# list run steps
run_steps = client.beta.threads.runs.steps.list(
  thread_id=thread.id,
  run_id=run.id
)
print(run_steps)
# Out:
# SyncCursorPage[RunStep](data=[RunStep(id='step_l0f69p4OySV0enDkK4IGNko7', assistant_id='asst_swfmOEk6qbwRmj1aqR8pBrqn', cancelled_at=None, completed_at=1702427772, created_at=1702427753, expired_at=None, failed_at=None, last_error=None, metadata=None, object='thread.run.step', run_id='run_eWjOvwchzq6bu9LfLampUqes', status='completed', step_details=MessageCreationStepDetails(message_creation=MessageCreation(message_id='msg_9ftZZp7Htb0bBwLrEfxZMUTT'), type='message_creation'), thread_id='thread_kPq2vL0g6zf8wj5zMg9coC3G', type='message_creation', expires_at=None)], object='list', first_id='step_l0f69p4OySV0enDkK4IGNko7', last_id='step_l0f69p4OySV0enDkK4IGNko7', has_more=False)
